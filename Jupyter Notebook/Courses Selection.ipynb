# %%
import pandas as pd
import numpy as np

# %%
course_info = pd.read_csv('datasets/cv_course_info.csv')

# %%
course_poster = pd.read_csv('datasets/cv_course_poster.csv')

# %%
course_video = pd.read_csv('datasets/cv_course_video.csv')

# %%
user_log = pd.read_csv('datasets/user_activity_log.csv')

# %%
user_info = pd.read_csv('datasets/user_info.csv')

# %%
user_score = pd.read_csv('datasets/user_test_score.csv')

# %%
watch_log = pd.read_csv('datasets/user_watch_log.csv')

# %%
# create compare dataframe
compare = pd.DataFrame(course_info[['cv_cid','course_title','roster_limit']])

# %%
compare.head()
# Out:
#                  cv_cid               course_title  roster_limit
# 0  USIS5STDNOBQGGHXDDG7   การควบคุมยาสูบ รุ่นที่ 4            45
# 1  ODRCRDFROFTNYRC0PQU2       Survival Thai (2016)            14
# 2  9W16HUAN3F0LB16BN1QC   การควบคุมยาสูบ รุ่นที่ 5            50
# 3  NTFBS3C5O5HPWTX9B8YJ  ภาษาอาหรับในชีวิตประจำวัน           100
# 4  P074WP7NLCCMPJ200PE8   การทำความเข้าใจงบการเงิน          2000

# %%
# find enrolled number
user_log[user_log['action_type'] == 'enrolled'].head()
# Out:
#      record_id                cv_uid                cv_cid action_type  \
# 19          20  8P5HPBLA2GOY32Q62L4H  7CRXZBIZG3065FGF1EX7    enrolled
# 42          43  FCSVBQ8XC3IHW7LKRMRV  BVMJQ55OFZ5QDHC9S6K0    enrolled
# 208        209  XO69MDF3E16J5VH93QZU  0FVWM6K4PO7GY7UMS0CV    enrolled
# 268        269  XO69MDF3E16J5VH93QZU  0FVWM6K4PO7GY7UMS0CV    enrolled
# 322        323  XO69MDF3E16J5VH93QZU  0FVWM6K4PO7GY7UMS0CV    enrolled
#
#                  assoc_id             assoc_id2   timestamp
# 19   4SSGRYQUWTF4N81YBKCG  SRGWN4LOSQEK8A51ENFQ  1530415549
# 42   4SSGRYQUWTF4N81YBKCG  SRGWN4LOSQEK8A51ENFQ  1530416999
# 208  4SSGRYQUWTF4N81YBKCG  SRGWN4LOSQEK8A51ENFQ  1530428594
# 268  4SSGRYQUWTF4N81YBKCG  SRGWN4LOSQEK8A51ENFQ  1530430759
# 322  4SSGRYQUWTF4N81YBKCG  SRGWN4LOSQEK8A51ENFQ  1530431854

# %%
enrolled = user_log[user_log['action_type'] == 'enrolled'][['cv_uid', 'cv_cid']]

# %%
enrolled = enrolled.drop_duplicates()

# %%
enrolled.head()
# Out:
#                    cv_uid                cv_cid
# 19   8P5HPBLA2GOY32Q62L4H  7CRXZBIZG3065FGF1EX7
# 42   FCSVBQ8XC3IHW7LKRMRV  BVMJQ55OFZ5QDHC9S6K0
# 208  XO69MDF3E16J5VH93QZU  0FVWM6K4PO7GY7UMS0CV
# 703  RYPPZTWA6ZIBO8KALUJQ  7CRXZBIZG3065FGF1EX7
# 708  33A17SXZ1D5GMEJ6IX50  7CRXZBIZG3065FGF1EX7

# %%
enrolled_df = pd.DataFrame(enrolled['cv_cid'].value_counts())
enrolled_df = enrolled_df.reset_index()
enrolled_df = enrolled_df.rename(columns={'index':'cv_cid', 'cv_cid':'enrolled'})

# %%
enrolled_df.head()
# Out:
#                  cv_cid  enrolled
# 0  4FGWS62JAC841KUL6OU5      5000
# 1  FW6GP1Z0HFS7NKLPRODK      5000
# 2  5A8YT3KKZLNDEKAFUC9G      4999
# 3  H1VF4W3F9NZWLNVU0AHX      4999
# 4  AJMXHLS4EAHHIEIBRUD2      4000

# %%
compare = pd.merge(left=compare, right=enrolled_df, how='outer', on='cv_cid')

# %%
compare.head()
# Out:
#                  cv_cid               course_title  roster_limit  enrolled
# 0  USIS5STDNOBQGGHXDDG7   การควบคุมยาสูบ รุ่นที่ 4            45       NaN
# 1  ODRCRDFROFTNYRC0PQU2       Survival Thai (2016)            14       NaN
# 2  9W16HUAN3F0LB16BN1QC   การควบคุมยาสูบ รุ่นที่ 5            50       NaN
# 3  NTFBS3C5O5HPWTX9B8YJ  ภาษาอาหรับในชีวิตประจำวัน           100       NaN
# 4  P074WP7NLCCMPJ200PE8   การทำความเข้าใจงบการเงิน          2000       NaN

# %%
# find completed number
user_log[user_log['action_type'].isin(['completed_intime', 'completed_late'])].head()
# Out:
#      record_id                cv_uid                cv_cid       action_type  \
# 10          11  XUIYIXBNCANH7PFXP2DY  QRYBHUNIP0IACOIL71TG  completed_intime
# 56          57  8MWSB2LM1ZHRP5MK0M0Y  6UPBLIGCIUERR27OAEQE    completed_late
# 75          76  ZQ1S2ANIIIAWVC47F4EC  FA6JAZ3XZFBY9NFCBFHD    completed_late
# 119        120  3UOHQSQO8LQ6RNAU82RP  UMF4ZAMAJ3UAKSY5URJR  completed_intime
# 129        130  JE2G7HHOLCM9289FQ8QZ  FA6JAZ3XZFBY9NFCBFHD    completed_late
#
#                  assoc_id             assoc_id2   timestamp
# 10   4SSGRYQUWTF4N81YBKCG  SRGWN4LOSQEK8A51ENFQ  1530414115
# 56   4SSGRYQUWTF4N81YBKCG  SRGWN4LOSQEK8A51ENFQ  1530418272
# 75   4SSGRYQUWTF4N81YBKCG  SRGWN4LOSQEK8A51ENFQ  1530419423
# 119  4SSGRYQUWTF4N81YBKCG  SRGWN4LOSQEK8A51ENFQ  1530423076
# 129  4SSGRYQUWTF4N81YBKCG  SRGWN4LOSQEK8A51ENFQ  1530424536

# %%
completed = user_log[user_log['action_type'].isin(['completed_intime', 'completed_late'])][['cv_uid', 'cv_cid']]

# %%
completed = completed.drop_duplicates()

# %%
completed.head()
# Out:
#                    cv_uid                cv_cid
# 10   XUIYIXBNCANH7PFXP2DY  QRYBHUNIP0IACOIL71TG
# 56   8MWSB2LM1ZHRP5MK0M0Y  6UPBLIGCIUERR27OAEQE
# 75   ZQ1S2ANIIIAWVC47F4EC  FA6JAZ3XZFBY9NFCBFHD
# 119  3UOHQSQO8LQ6RNAU82RP  UMF4ZAMAJ3UAKSY5URJR
# 129  JE2G7HHOLCM9289FQ8QZ  FA6JAZ3XZFBY9NFCBFHD

# %%
completed_df = pd.DataFrame(completed['cv_cid'].value_counts())
completed_df = completed_df.reset_index()
completed_df = completed_df.rename(columns={'index':'cv_cid', 'cv_cid':'completed'})

# %%
completed_df.head()
# Out:
#                  cv_cid  completed
# 0  KTDV6J95MMM8T3NYTKJ8       1326
# 1  4FGWS62JAC841KUL6OU5        963
# 2  AJMXHLS4EAHHIEIBRUD2        955
# 3  1RJTD3WGX1GRFVMKS8L8        947
# 4  58PVKVFVINRFOK7CNA53        934

# %%
compare = pd.merge(left=compare, right=completed_df, how='outer', on='cv_cid')

# %%
compare.head()
# Out:
#                  cv_cid               course_title  roster_limit  enrolled  \
# 0  USIS5STDNOBQGGHXDDG7   การควบคุมยาสูบ รุ่นที่ 4            45       NaN
# 1  ODRCRDFROFTNYRC0PQU2       Survival Thai (2016)            14       NaN
# 2  9W16HUAN3F0LB16BN1QC   การควบคุมยาสูบ รุ่นที่ 5            50       NaN
# 3  NTFBS3C5O5HPWTX9B8YJ  ภาษาอาหรับในชีวิตประจำวัน           100       NaN
# 4  P074WP7NLCCMPJ200PE8   การทำความเข้าใจงบการเงิน          2000       NaN
#
#    completed
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# find quiz submitted number (รวมส่งซ้ำ)
user_log[user_log['action_type'] == 'quiz_submitted'].head(5)
# Out:
#    record_id                cv_uid                cv_cid     action_type  \
# 0          1  KP0XGECF1SGVOS2O24VF  UMF4ZAMAJ3UAKSY5URJR  quiz_submitted
# 1          2  KP0XGECF1SGVOS2O24VF  UMF4ZAMAJ3UAKSY5URJR  quiz_submitted
# 2          3  KP0XGECF1SGVOS2O24VF  UMF4ZAMAJ3UAKSY5URJR  quiz_submitted
# 3          4  KP0XGECF1SGVOS2O24VF  UMF4ZAMAJ3UAKSY5URJR  quiz_submitted
# 6          7  V58JVMDBJNDKCYHSRHHL  I8DFH7UV5ZTLVFVIRXU3  quiz_submitted
#
#                assoc_id             assoc_id2   timestamp
# 0  JMYCQPQ9ZCPXEEEMSHIH  SRGWN4LOSQEK8A51ENFQ  1530413688
# 1  JMYCQPQ9ZCPXEEEMSHIH  SRGWN4LOSQEK8A51ENFQ  1530413709
# 2  JMYCQPQ9ZCPXEEEMSHIH  SRGWN4LOSQEK8A51ENFQ  1530413724
# 3  JMYCQPQ9ZCPXEEEMSHIH  SRGWN4LOSQEK8A51ENFQ  1530413741
# 6  HHU5MK19PUFUIRU7F6HM  CZNQBKD7QR443LYEPNCF  1530414023

# %%
submitted = user_log[user_log['action_type'] == 'quiz_submitted'][['cv_uid', 'cv_cid', 'assoc_id', 'assoc_id2']]

# %%
submitted = submitted.drop_duplicates()

# %%
submitted.head()
# Out:
#                   cv_uid                cv_cid              assoc_id  \
# 0   KP0XGECF1SGVOS2O24VF  UMF4ZAMAJ3UAKSY5URJR  JMYCQPQ9ZCPXEEEMSHIH
# 6   V58JVMDBJNDKCYHSRHHL  I8DFH7UV5ZTLVFVIRXU3  HHU5MK19PUFUIRU7F6HM
# 9   XUIYIXBNCANH7PFXP2DY  QRYBHUNIP0IACOIL71TG  86TBVVP582ZNYVOT738N
# 11  KH8UA5P183ESRY8BQSNP  7M978UYOQ7J2A0EGDK3D  83PK3M4EQRNVOPDASXCL
# 18  V58JVMDBJNDKCYHSRHHL  I8DFH7UV5ZTLVFVIRXU3  14EUFYJG546CBJ1ZV0NV
#
#                assoc_id2
# 0   SRGWN4LOSQEK8A51ENFQ
# 6   CZNQBKD7QR443LYEPNCF
# 9   SRGWN4LOSQEK8A51ENFQ
# 11  7LSY9RBX6NM0NX4RC4RY
# 18  RG6NN0U9WU31P51TD7PY

# %%
submitted_df = pd.DataFrame(submitted['cv_cid'].value_counts())
submitted_df = submitted_df.reset_index()
submitted_df = submitted_df.rename(columns={'index':'cv_cid', 'cv_cid':'submitted'})

# %%
submitted_df.head()
# Out:
#                  cv_cid  submitted
# 0  FC6VM7RQT38Z0ZI9M6W9      23535
# 1  QHFKPN7D6QDV9226ZDHW      16293
# 2  OTS26V4DL3U4LE4YHWAF      13896
# 3  SNF5FFS045YAV05CVAUR      13719
# 4  WJRPZZZ2IEYBGO5YLJ4U      12739

# %%
compare = pd.merge(left=compare, right=submitted_df, how='outer', on='cv_cid')

# %%
compare.head()
# Out:
#                  cv_cid               course_title  roster_limit  enrolled  \
# 0  USIS5STDNOBQGGHXDDG7   การควบคุมยาสูบ รุ่นที่ 4            45       NaN
# 1  ODRCRDFROFTNYRC0PQU2       Survival Thai (2016)            14       NaN
# 2  9W16HUAN3F0LB16BN1QC   การควบคุมยาสูบ รุ่นที่ 5            50       NaN
# 3  NTFBS3C5O5HPWTX9B8YJ  ภาษาอาหรับในชีวิตประจำวัน           100       NaN
# 4  P074WP7NLCCMPJ200PE8   การทำความเข้าใจงบการเงิน          2000       NaN
#
#    completed  submitted
# 0        NaN        1.0
# 1        NaN        NaN
# 2        NaN        3.0
# 3        NaN        NaN
# 4        NaN       84.0

# %%
# find video number
course_video['video_source_id'].value_counts().sort_values(ascending=False).head()
# Out:
# VB79884A9OC2KYK6H3WB    13
# 0IP5T4N5DGVHT3EGAE7N    12
# H1T0YRDPB01KVKHFZKBE    10
# C8FTU58NAFLQV6ZQOJLM    10
# IU6HALYFSZICOLXYFY5M    10
# Name: video_source_id, dtype: int64

# %%
video = course_video[['cv_cid', 'video_source_id']]

# %%
video = video.drop_duplicates()

# %%
video.head()
# Out:
#                   cv_cid       video_source_id
# 0   USIS5STDNOBQGGHXDDG7  VB79884A9OC2KYK6H3WB
# 13  USIS5STDNOBQGGHXDDG7  BZV2DEBTCWJQZ9XJSTUM
# 14  USIS5STDNOBQGGHXDDG7  1WF44SB950QHYX0BJWAB
# 15  USIS5STDNOBQGGHXDDG7  7YMR655ZVGKIFFP7I922
# 16  USIS5STDNOBQGGHXDDG7  JAIGN1Y42Z1HF7ZFZWIO

# %%
video_df = pd.DataFrame(video['cv_cid'].value_counts())
video_df = video_df.reset_index()
video_df = video_df.rename(columns={'index':'cv_cid', 'cv_cid':'video'})

# %%
video_df.head()
# Out:
#                  cv_cid  video
# 0  05D56Q0SK46GK59IAFJZ     47
# 1  LRQ3O125BDTDCHUI6CL3     46
# 2  IUVK8F29KDGDF29B1FY3     46
# 3  GO9R3FH2T2WXZO77V2LB     46
# 4  1E4ZGDM7EPGXFLDK98QY     45

# %%
compare = pd.merge(left=compare, right=video_df, how='outer', on='cv_cid')

# %%
compare.head()
# Out:
#                  cv_cid               course_title  roster_limit  enrolled  \
# 0  USIS5STDNOBQGGHXDDG7   การควบคุมยาสูบ รุ่นที่ 4          45.0       NaN
# 1  ODRCRDFROFTNYRC0PQU2       Survival Thai (2016)          14.0       NaN
# 2  9W16HUAN3F0LB16BN1QC   การควบคุมยาสูบ รุ่นที่ 5          50.0       NaN
# 3  NTFBS3C5O5HPWTX9B8YJ  ภาษาอาหรับในชีวิตประจำวัน         100.0       NaN
# 4  P074WP7NLCCMPJ200PE8   การทำความเข้าใจงบการเงิน        2000.0       NaN
#
#    completed  submitted  video
# 0        NaN        1.0   25.0
# 1        NaN        NaN   15.0
# 2        NaN        3.0   35.0
# 3        NaN        NaN   26.0
# 4        NaN       84.0   26.0

# %%
compare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 0 to 181
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cv_cid        182 non-null    object
#  1   course_title  175 non-null    object
#  2   roster_limit  175 non-null    float64
#  3   enrolled      105 non-null    float64
#  4   completed     85 non-null     float64
#  5   submitted     126 non-null    float64
#  6   video         166 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 11.4+ KB

# %%
compare.sort_values(['completed'], ascending=False).head(10)
# Out:
#                    cv_cid                                       course_title  \
# 136  KTDV6J95MMM8T3NYTKJ8           Critical Thinking for Business รุ่นที่ 3
# 71   4FGWS62JAC841KUL6OU5  มหากาพย์ อังกฤษ อัพเกรด : โค้งสุดท้ายไวยากรณ์ ...
# 82   AJMXHLS4EAHHIEIBRUD2                    การตลาดในศตวรรษที่ 21 รุ่นที่ 3
# 63   1RJTD3WGX1GRFVMKS8L8           มหากาพย์ อังกฤษ อัพเกรด: ตั้งไข่ไวยากรณ์
# 100  58PVKVFVINRFOK7CNA53  Unicorn journey: Startup Your Own Business, Mo...
# 127  OTS26V4DL3U4LE4YHWAF  ทำอย่างไรให้สินค้า Go Inter ขายได้ขายดี และดัง...
# 129  9301L5BFKAFLGFS5P0BH                            English for Job Hunters
# 83   324D932IBH0ECPJJ47EZ  Unicorn journey: Startup Your Own Business, Mo...
# 73   H1VF4W3F9NZWLNVU0AHX       มหากาพย์ อังกฤษ อัพเกรด: Conversation มั่นใจ
# 72   FW6GP1Z0HFS7NKLPRODK      มหากาพย์ อังกฤษ อัพเกรด : ศัพท์ทะลุ อ่านทะลวง
#
#      roster_limit  enrolled  completed  submitted  video
# 136        4000.0    4000.0     1326.0    12635.0   15.0
# ...

# %%
compare.dropna(inplace=True)

# %%
compare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73 entries, 17 to 150
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cv_cid        73 non-null     object
#  1   course_title  73 non-null     object
#  2   roster_limit  73 non-null     float64
#  3   enrolled      73 non-null     float64
#  4   completed     73 non-null     float64
#  5   submitted     73 non-null     float64
#  6   video         73 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 4.6+ KB

# %%
compare['year'] = course_info['year']

# %%
compare['course_type'] = course_info['course_type']

# %%
compare['reg_workflow'] = course_info['reg_workflow']

# %%
compare.sort_values(['completed'], ascending=False).head(10)
# Out:
#                    cv_cid                                       course_title  \
# 136  KTDV6J95MMM8T3NYTKJ8           Critical Thinking for Business รุ่นที่ 3
# 71   4FGWS62JAC841KUL6OU5  มหากาพย์ อังกฤษ อัพเกรด : โค้งสุดท้ายไวยากรณ์ ...
# 82   AJMXHLS4EAHHIEIBRUD2                    การตลาดในศตวรรษที่ 21 รุ่นที่ 3
# 63   1RJTD3WGX1GRFVMKS8L8           มหากาพย์ อังกฤษ อัพเกรด: ตั้งไข่ไวยากรณ์
# 100  58PVKVFVINRFOK7CNA53  Unicorn journey: Startup Your Own Business, Mo...
# 127  OTS26V4DL3U4LE4YHWAF  ทำอย่างไรให้สินค้า Go Inter ขายได้ขายดี และดัง...
# 129  9301L5BFKAFLGFS5P0BH                            English for Job Hunters
# 83   324D932IBH0ECPJJ47EZ  Unicorn journey: Startup Your Own Business, Mo...
# 73   H1VF4W3F9NZWLNVU0AHX       มหากาพย์ อังกฤษ อัพเกรด: Conversation มั่นใจ
# 72   FW6GP1Z0HFS7NKLPRODK      มหากาพย์ อังกฤษ อัพเกรด : ศัพท์ทะลุ อ่านทะลวง
#
#      roster_limit  enrolled  completed  submitted  video  year course_type  \
# ...

# %%
compare.sort_values(['submitted'], ascending=False).head(10)
# Out:
#                    cv_cid                                       course_title  \
# 87   FC6VM7RQT38Z0ZI9M6W9                 การทำความเข้าใจงบการเงิน รุ่นที่ 3
# 128  QHFKPN7D6QDV9226ZDHW     Intro to Data Analytics and Big Data รุ่นที่ 4
# 127  OTS26V4DL3U4LE4YHWAF  ทำอย่างไรให้สินค้า Go Inter ขายได้ขายดี และดัง...
# 80   SNF5FFS045YAV05CVAUR     Intro to Data Analytics and Big Data รุ่นที่ 3
# 138  WJRPZZZ2IEYBGO5YLJ4U               การประชาสัมพันธ์ผ่านวิทยุและโทรทัศน์
# 136  KTDV6J95MMM8T3NYTKJ8           Critical Thinking for Business รุ่นที่ 3
# 82   AJMXHLS4EAHHIEIBRUD2                    การตลาดในศตวรรษที่ 21 รุ่นที่ 3
# 126  WJT59AIPVL7M0WV7C6FW                    ดนตรีคลาสสิกปริทรรศน์ รุ่นที่ 2
# 102  GGJQFI40Q64PPLBWACZX                        Data Analytics and Big Data
# 62   97Q1CLKIGWEFNTWFZLIQ                              ดนตรีคลาสสิกปริทรรศน์
#
#      roster_limit  enrolled  completed  submitted  video  year course_type  \
# ...

# %%
compare[compare['reg_workflow'] == 'purchase_to_enroll'].sort_values('enrolled', ascending=False).head()
# Out:
#                    cv_cid                                       course_title  \
# 83   324D932IBH0ECPJJ47EZ  Unicorn journey: Startup Your Own Business, Mo...
# 100  58PVKVFVINRFOK7CNA53  Unicorn journey: Startup Your Own Business, Mo...
# 101  RGXI6CNPQH13VA73F755  Competing in a Data-Driven World: Understand a...
# 120  W12XLYO9SIA2S2RVOL6N  Liver scanning protocol: Liver disease and Sur...
# 134  C3C08QNNXXDFWIVUEDAL  Unicorn journey: Startup Your Own Business, Mo...
#
#      roster_limit  enrolled  completed  submitted  video  year course_type  \
# 83         2200.0    1069.0      852.0     1013.0    4.0  2018    selfpace
# 100        2200.0     994.0      934.0      964.0    3.0  2018    selfpace
# 101        3000.0     594.0      181.0     3787.0   27.0  2018    selfpace
# 120         520.0     503.0       50.0      370.0    4.0  2018    selfpace
# 134        2200.0     465.0      392.0      449.0    6.0  2018    selfpace
#
#            reg_workflow
# 83   purchase_to_enroll
# ...

# %%
compare.sort_values(['completed'], ascending=False).head(40)
# Out:
#                    cv_cid                                       course_title  \
# 136  KTDV6J95MMM8T3NYTKJ8           Critical Thinking for Business รุ่นที่ 3
# 71   4FGWS62JAC841KUL6OU5  มหากาพย์ อังกฤษ อัพเกรด : โค้งสุดท้ายไวยากรณ์ ...
# 82   AJMXHLS4EAHHIEIBRUD2                    การตลาดในศตวรรษที่ 21 รุ่นที่ 3
# 63   1RJTD3WGX1GRFVMKS8L8           มหากาพย์ อังกฤษ อัพเกรด: ตั้งไข่ไวยากรณ์
# 100  58PVKVFVINRFOK7CNA53  Unicorn journey: Startup Your Own Business, Mo...
# 127  OTS26V4DL3U4LE4YHWAF  ทำอย่างไรให้สินค้า Go Inter ขายได้ขายดี และดัง...
# 129  9301L5BFKAFLGFS5P0BH                            English for Job Hunters
# 83   324D932IBH0ECPJJ47EZ  Unicorn journey: Startup Your Own Business, Mo...
# 73   H1VF4W3F9NZWLNVU0AHX       มหากาพย์ อังกฤษ อัพเกรด: Conversation มั่นใจ
# 72   FW6GP1Z0HFS7NKLPRODK      มหากาพย์ อังกฤษ อัพเกรด : ศัพท์ทะลุ อ่านทะลวง
# 137  FNONNX6ZNA8NP3F1FCTV  มหากาพย์ อังกฤษ อัพเกรด: ตั้งไข่ไวยากรณ์ รุ่นท...
# ...
